# %% [markdown]
# # Loan Approval Prediction using Machine Learning
#
# ### This project aims to predict whether a loan application will be approved or rejected based on applicant details.

# %% [markdown]
# ## PHASE 1: Understand & Load Data

# %% [markdown]
# ### 1.1 Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.2 Load data

# %%
df = pd.read_csv("../data/loan_approval_dataset.csv")

# %% [markdown]
# ### 1.3 Analysis of unprocessed/raw data

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   str
#  3    self_employed             4269 non-null   str
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   str
# dtypes: int64(10), str(3)
# memory usage: 433.7 KB

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %% [raw]
# Observation (Raw Data):
#
# 1. The dataset contains financial and demographic details of loan applicants such as income, loan amount, CIBIL score, and asset values.
# 2. There is an unnecessary column 'loan_id' which does not contribute to prediction.
# 3. Some features like 'education' and 'self_employed' are categorical in nature.
# 4. The target variable 'loan_status' is categorical (Approved/Rejected).
# 5. No missing values are observed in the dataset.
# 6. Features such as CIBIL score, income, and asset values are likely to play an important role in determining loan approval.

# %% [markdown]
# ## PHASE 2: Data Preprocessing

# %%
df.columns = df.columns.str.strip() # removal of unnecessary space
df.drop("loan_id", axis=1, inplace=True) # removal of loan id not needed

# %%
# Mapping loan_status:- approved -> 1   rejected -> 0
df['loan_status'] = df['loan_status'].astype(str) # making it of string type
df['loan_status'] = df['loan_status'].str.strip() # removing extra space if any
df['loan_status'] = df['loan_status'].map({'Approved': 1, 'Rejected': 0}) # mapping

# %% [raw]
# df['loan_status'] = df['loan_status'].map({'Approved': 1, 'Rejected': 0})
# writing only this in above cell will create error :- Because of inconsistent formatting like extra spaces in categorical values.
# Because of spaces → mapping will fail -> everything became NaN (float) -> .str.strip() will fail because Column is no longer string

# %%
df
# Out:
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# ...

# %%
df.isnull().sum()
# Out:
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
# Convert categorical columns - Text -> numbers
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in df.select_dtypes(include=['object', 'string']).columns:
    df[col] = le.fit_transform(df[col])

# %%
# I got a warning when I wrote df.select_dtypes(include='object') because:-
# object includes text columns in future pandas will separate object and string

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no_of_dependents          4269 non-null   int64
#  1   education                 4269 non-null   int64
#  2   self_employed             4269 non-null   int64
#  3   income_annum              4269 non-null   int64
#  4   loan_amount               4269 non-null   int64
#  5   loan_term                 4269 non-null   int64
#  6   cibil_score               4269 non-null   int64
#  7   residential_assets_value  4269 non-null   int64
#  8   commercial_assets_value   4269 non-null   int64
#  9   luxury_assets_value       4269 non-null   int64
#  10  bank_asset_value          4269 non-null   int64
#  11  loan_status               4269 non-null   int64
# dtypes: int64(12)
# memory usage: 400.3 KB

# %% [raw]
# Observation (Processed Data):
#
# 1. Column names were cleaned and unnecessary columns like 'loan_id' were removed.
# 2. The target variable 'loan_status' was successfully converted into numerical format (1 = Approved, 0 = Rejected).
# 3. All categorical features were encoded into numerical values for model compatibility.
# 3. No missing values remain in the dataset after preprocessing.
# 4. The dataset is now fully numerical and ready for machine learning model training.

# %% [markdown]
# ## PHASE 3: Exploratory Data Analysis(EDA)

# %% [markdown]
# ### 3.1 Loan Status Distribution

# %%
sns.countplot(x='loan_status', data=df)
plt.title("Loan Status Distribution")
plt.show()

# %% [raw]
# Observation:
# The dataset shows that the number of approved loans is higher than rejected loans, indicating a slight class imbalance towards approved applications. However, the imbalance is not extreme, so it is unlikely to significantly affect model performance.

# %% [markdown]
# ### 3.2 Income Distribution

# %%
sns.histplot(df['income_annum'], kde=True)
plt.title("Income Distribution")
plt.show()

# %% [raw]
# Observation:
#
# The income distribution appears to be fairly uniform across a wide range of values, indicating that applicants belong to diverse income groups. There is no strong skewness, suggesting that the dataset includes both low and high income individuals without heavy concentration in a specific range.

# %% [markdown]
# ### 3.3 CIBIL Score Distribution

# %%
sns.histplot(df['cibil_score'], kde=True)
plt.title("CIBIL Score Distribution")
plt.show()

# %% [raw]
# Observation:
#
# The CIBIL score distribution is fairly uniform across the range of 300 to 900, indicating a wide variety of credit profiles among applicants. A significant number of applicants have moderate to high credit scores, suggesting generally good creditworthiness in the dataset.

# %% [markdown]
# ### 3.4 Income vs Loan Status

# %%
sns.boxplot(x='loan_status', y='income_annum', data=df)
plt.title("Income vs Loan Status")
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# The income distribution for approved and rejected loan applications appears to be quite similar, with comparable median values and spread. This suggests that income alone may not be a strong distinguishing factor in determining loan approval.

# %% [markdown]
# ### 3.5 CIBIL Score vs Loan Status

# %%
sns.boxplot(x='loan_status', y='cibil_score', data=df)
plt.title("CIBIL Score vs Loan Status")
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# The CIBIL score shows a strong relationship with loan approval. Applicants with higher CIBIL scores are significantly more likely to have their loans approved, while those with lower scores are mostly rejected. This indicates that CIBIL score is one of the most influential factors in determining loan approval.

# %% [markdown]
# ### 3.6 Assets vs Loan Status

# %%
sns.boxplot(x='loan_status', y='residential_assets_value', data=df)
plt.title("Assets vs Loan Status")
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# The distribution of residential asset values for approved and rejected loan applications appears to be quite similar, with comparable median values. Although applicants with higher assets may have a slightly higher chance of approval, asset value alone does not strongly differentiate between approved and rejected loans.

# %% [markdown]
# ### 3.7 Correlation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# 1. The correlation matrix shows that most features have low correlation with the target variable (loan_status), except for the CIBIL score, which has a strong positive correlation. This confirms that CIBIL score is the most important factor influencing loan approval.
#
# 2. Strong correlations are observed between income, loan amount, and asset-related features, indicating multicollinearity among these variables. This suggests that these features may carry similar information and should be handled carefully during model building.

# %% [markdown]
# ### 3.8 EDA Observation:

# %% [raw]
# 1. The target variable shows a slight class imbalance, with more approved loans than rejected ones, though the imbalance is not severe.
#
# 2. The CIBIL score stands out as the most influential factor, showing a strong positive relationship with loan approval. Applicants with higher credit scores are significantly more likely to get their loans approved.
#
# 3. Income and asset-related features such as residential, commercial, luxury, and bank asset values show moderate relationships with loan approval but do not independently determine the outcome. Additionally, these features are highly correlated with each other, indicating multicollinearity.
#
# 4. Categorical features like education, number of dependents, and self-employment status show very weak relationships with loan approval, suggesting limited predictive power.
#
# Overall, the analysis indicates that creditworthiness (CIBIL score) is the key driver of loan approval, while other financial features contribute collectively but are less decisive on their own.
